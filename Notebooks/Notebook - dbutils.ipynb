# %%
# %python
dbutils.help()

# %%
dbutils.fs.help()

# %%
display(dbutils.fs.ls('/Volumes/dev_ext/sdi_ext/vol_ext/files'))

# %%
display(dbutils.fs.head('/Volumes/dev_ext/sdi_ext/vol_ext/files/emp.csv'))

# %% [markdown]
# # Widgets - Parameters initials

# %%
dbutils.widgets.help()

# %%
# %sql
select * from csv.`/Volumes/dev_ext/sdi_ext/vol_ext/files/emp.csv`;

# %%
dbutils.widgets.text('dept_id', '101', 'Department ID')

# %%
dbutils.widgets.get('dept_id')

# %%
# %sql
    
select ${dept_id}

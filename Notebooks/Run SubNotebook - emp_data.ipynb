# %%
help(dbutils.notebook.run)

# %%
dbutils.notebook.run(
    "Read_Write_emp_data",
    600,
    {"dept_id": "101"}
)

# %%
dbutils.notebook.run(
    "Read_Write_emp_data",
    600,
    {"dept_id": "102"}
)

# %%
# %sql
select * from dev_ext.sdi.emp_101;

# %%
# %sql
select * from dev_ext.sdi.emp_102;

# %%
# %sql
drop table dev_ext.sdi.emp_101;
drop table dev_ext.sdi.emp_102;

# %%
# %sql
select * from dev_ext.sdi.emp_101
union all
select * from dev_ext.sdi.emp_102
union all
select * from dev_ext.sdi.emp_103
order by department_id;
